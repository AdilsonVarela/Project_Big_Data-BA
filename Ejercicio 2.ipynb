# %% [markdown]
# #  EJERCICIO 2

# %% [markdown]
# 1- Tomamos el archivo sentimientos.txt como uno de los archivos de entrada, donde podemos acceder a los sentimientos y sus respectivos valores.

# %%
# ---------------------------archivo de lectura sientimiento.txt------------
valores = {} 
for linea in open("Sentimientos.txt"): 
    termino, valor = linea.split("\t") 
    valores[termino] = int(valor) 
#print (valores.items())

# %% [markdown]
# 2- De manera similar Ejercicio1, para calcular la suma de valores de sentimientos, se creó una función llamada soma_valor que recibe una lista de valores de sentimeintos. Esta función fue útil para implementar la versión 1 con una técnica para asignar valores a conjuntos de palabras o palabras que no tienen ningún valor asociado. El ejemplo sigue.

# %%
Por Ejemplo:
    
SENTIMIENTO(S): beautiful = 3
-----------------------------------

SENTIMIENTO(S): better = 2
-----------------------------------

You : 5
believe : 5
your : 5
---------- COMPROBAR-----------
EL SEGUINTE TWEET: ['You', 'better', 'believe', 'your', 'beautiful'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 5

# %%
#----------------------funcion soma_valor -------------------
def soma_valor(valor):
    soma = 0
    for i in valor:
        soma+=i
  
    return soma

# %% [markdown]
# 3- De acuerdo con los requisitos del ejercicio, a una palabra o conjunto de palabras que no tiene un valor asociado se le asignará un valor, una de las técnicas para asignar estos valores fue el número de palabras en el tweet dividido por el valor del sentimiento del tweet. La función med_tweer es responsable de implementar esta técnica. El ejemplo sigue

# %%
SENTIMIENTO(S): beautiful = 3
----------------------------------

SENTIMIENTO(S): better = 2
-----------------------------------

You : 1.0
believe : 1.0
your : 1.0
---------- COMPROBAR-----------
EL SEGUINTE TWEET: ['You', 'better', 'believe', 'your', 'beautiful'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 5
____________________________________________________________________________________________________________

# %%
#---------------------------function media tweet----------------
def med_tweer (len_tweet,v_sent):
            
            res=(len_tweet/v_sent)
    
            return round (res,3)

# %% [markdown]
# 4- La función print_json es responsable de prácticamente todos los ejercicios. Le permite leer el archivo Tweet.txt a través de json_loads (), de forma análoga al Ejercicio 1, las líneas del archivo Tweet.txt están en el diccionario anidado, esta función sirve para descomprimir las líneas que están en el diccionario anidado y las otras técnicas para cumplir con los requisitos de ejercicio. Un poco diferente del ejercicio 1, aquí se agregó otro parámetro (valor_vers) que recibe el valor 1 o 2, un valor que determina la técnica para asignar valores a palabras o conjuntos de palabras que no tienen valores (Versión 1, asignando el valor del sentimiento del twittea las palabras o la Versión 2, asignando la media del valor del tweet, mientras que esta es la media del número de palabras del tweet divididas entre el valor de sentimiento del tweet).

# %%
#----------------------funcion print_json -------------------

def print_json(data,k,valor_vers):
    
        if type(data) == dict:
                for k, v in data.items():
                    if (isinstance(v,str) or isinstance(v,dict)):
                        print_json(v,k,valor_vers)

        else:
            valor=[]
            list_sent=[]
            tweet_list=[]
            data=data.split(" ")
            if (type(data) is list and data !=None) : 
                                    
                for sent, k in valores.items():
                    if sent in data:
                        valor.append(k)
                        list_sent.append(sent)
                        print("SENTIMIENTO(S):", sent,"=",k,) 
                        print("-----------------------------------\n")        

                              
                num_ass=soma_valor(valor)
                if num_ass!=0:
                   
                    if valor_vers==1:
                        for tweet in data:
                            
                            if tweet not in list_sent:
                                print(tweet,":",num_ass)

                        print("---------- COMPROBAR-----------")
                        print("EL SEGUINTE TWEET:",data,"," " ""TIENE UN SENTIMIENTO ASSOCIADO DE:",num_ass)
                        print("________________________________________________________________________________________________________________\n")
                        
                    elif valor_vers==2:
                        
                        for tweet in data:
                            if tweet not in list_sent :
                                media=med_tweer(len(data),num_ass)
                                print(tweet,":",media)

                        print("---------- COMPROBAR-----------")
                        print("EL SEGUINTE TWEET:",data,"," " ""TIENE UN SENTIMIENTO ASSOCIADO DE:",num_ass)
                        print("______________________________________________________________________________________________________________________\n")

# %% [markdown]
# 5- El siguiente script es responsable de leer el archivo Tweet.txt a través de json_loads (), es responsable de llamar a la función print_json y también validar los valores para elegir la versión para asignar números a palabras o conjuntos de palabras que no tienen valores , no se aceptarán valores distintos de 1 o 2 para avanzar en el programa.

# %%
# ---------------------------archivo de lectura sientimiento.txt------------
import json
print("Este ejercicio se realiza en dos versiones. Elija la versión 1 (Valor 1) o la versión 2 (Valor 2):")
valor_vers=int(input("Elija la versión:"))
if valor_vers==1:
    print("Versión 1, asignando el valor del sentimiento del tweet a las palabras:\n")
elif  valor_vers==2:
    print("Versión 2, asignando la media del valor del tweet, siendo esta media el número de palabras del tweet dividido entre el valor de sentimiento del tweet;:\n")

if (valor_vers ==1 or valor_vers==2):
    for line in open('Tweets.txt', 'r'):
            valor=json.loads(line)
            print_json(valor,0,valor_vers)
else:
    print("Elija la versión 1 o 2!!")
# Out:
# Este ejercicio se realiza en dos versiones. Elija la versión 1 (Valor 1) o la versión 2 (Valor 2):
# Elija la versión:1
# Versión 1, asignando el valor del sentimiento del tweet a las palabras:
#
# SENTIMIENTO(S): united = 1
# -----------------------------------
#
# kingdom : 1
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['united', 'kingdom'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 1
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): ugly = -3
# -----------------------------------
#
# @hailee_danielsx : -3
# I'm : -3
# not : -3
# mean : -3
# cuz : -3
# I'm : -3
# so : -3
# ya : -3
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['@hailee_danielsx', "I'm", 'not', 'mean', 'cuz', "I'm", 'ugly', 'so', 'ya'] , TIENE UN SENTIMIENTO ASSOCIADO DE: -3
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): beautiful = 3
# -----------------------------------
#
# SENTIMIENTO(S): better = 2
# -----------------------------------
#
# You : 5
# believe : 5
# your : 5
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['You', 'better', 'believe', 'your', 'beautiful'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 5
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): love = 3
# -----------------------------------
#
# its : 3
# JSMV : 3
# here, : 3
# we : 3
# stevienorrisxo : 3
# support, : 3
# but : 3
# we : 3
# her : 3
# fish : 3
# tongue : 3
# even : 3
# more : 3
# #TeamJSMV : 3
# #TeamFishTongue : 3
# @JSMVOfficial : 3
# @BaileyMac02 : 3
# @thescript : 3
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['its', 'JSMV', 'here,', 'we', 'love', 'stevienorrisxo', 'support,', 'but', 'we', 'love', 'her', 'fish', 'tongue', 'even', 'more', '#TeamJSMV', '#TeamFishTongue', '@JSMVOfficial', '@BaileyMac02', '@thescript'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 3
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): no = -1
# -----------------------------------
#
# me : -1
# segue : -1
# @caralhovcs : -1
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['me', 'segue', 'no', '@caralhovcs'] , TIENE UN SENTIMIENTO ASSOCIADO DE: -1
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): no = -1
# -----------------------------------
#
# ღ : -1
# La : -1
# distancia : -1
# impide : -1
# un : -1
# beso : -1
# o : -1
# un : -1
# abrazo, : -1
# pero : -1
# impide : -1
# un : -1
# sentimiento : -1
# ღ : -1
# ∞@AbrahamMateoMus : -1
# sueños : -1
# cumplidos : -1
# gracias : -1
# a : -1
# ti∞ : -1
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['ღ', 'La', 'distancia', 'impide', 'un', 'beso', 'o', 'un', 'abrazo,', 'pero', 'no', 'impide', 'un', 'sentimiento', 'ღ', '∞@AbrahamMateoMus', 'sueños', 'cumplidos', 'gracias', 'a', 'ti∞'] , TIENE UN SENTIMIENTO ASSOCIADO DE: -1
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): tout = -2
# -----------------------------------
#
# Tout : -2
# est : -2
# toxique, : -2
# rien : -2
# n'est : -2
# toxique, : -2
# est : -2
# question : -2
# de : -2
# dose! : -2
# Professeur : -2
# agrégé : -2
# de : -2
# Physique : -2
# et : -2
# Chimie. : -2
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['Tout', 'est', 'toxique,', 'rien', "n'est", 'toxique,', 'tout', 'est', 'question', 'de', 'dose!', 'Professeur', 'agrégé', 'de', 'Physique', 'et', 'Chimie.'] , TIENE UN SENTIMIENTO ASSOCIADO DE: -2
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): no = -1
# -----------------------------------
#
# Novo : -1
# disco : -1
# gravado : -1
# ao : -1
# vivo : -1
# em : -1
# sorocaba : -1
# e : -1
# moema : -1
# soul : -1
# em : -1
# moema : -1
#
#
# Acompanhem : -1
# pelo : -1
# http://youtube.com/idade30 : -1
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['Novo', 'disco', 'gravado', 'ao', 'vivo', 'em', 'sorocaba', 'e', 'no', 'moema', 'soul', 'em', 'moema', '\r\n\r\nAcompanhem', 'pelo', 'http://youtube.com/idade30'] , TIENE UN SENTIMIENTO ASSOCIADO DE: -1
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): best = 3
# -----------------------------------
#
# SENTIMIENTO(S): good = 3
# -----------------------------------
#
# RT : 6
# @Nashgrier: : 6
# Happy : 6
# Birthday : 6
# to : 6
# one : 6
# of : 6
# my : 6
# friends : 6
# @jackgilinsky : 6
# Can't : 6
# wait : 6
# till : 6
# you're : 6
# out : 6
# in : 6
# LA! : 6
# Have : 6
# a : 6
# one! : 6
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['RT', '@Nashgrier:', 'Happy', 'Birthday', 'to', 'one', 'of', 'my', 'best', 'friends', '@jackgilinsky', "Can't", 'wait', 'till', "you're", 'out', 'in', 'LA!', 'Have', 'a', 'good', 'one!'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 6
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): dream = 1
# -----------------------------------
#
# SENTIMIENTO(S): no = -1
# -----------------------------------
#
# SENTIMIENTO(S): pressure = -1
# -----------------------------------
#
# There : -1
# is : -1
# when : -1
# you're : -1
# making : -1
# a : -1
# come : -1
# true^.- : -1
# @camerondallas : -1
# ♥ : -1
#  : -1
#  : -1
# @Nashgrier : -1
#  : -1
# ♥ : -1
#  : -1
#  : -1
# @TheMattEspinosa : -1
#  : -1
#  : -1
# ♥@JacobWhitesides : -1
#  : -1
#  : -1
#  : -1
# ♥Plzz : -1
# Follow : -1
# me♥ : -1
# ^.- : -1
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['There', 'is', 'no', 'pressure', 'when', "you're", 'making', 'a', 'dream', 'come', 'true^.-', '@camerondallas', '♥', '', '', '@Nashgrier', '', '♥', '', '', '@TheMattEspinosa', '', '', '♥@JacobWhitesides', '', '', '', '♥Plzz', 'Follow', 'me♥', '^.-'] , TIENE UN SENTIMIENTO ASSOCIADO DE: -1
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): best = 3
# -----------------------------------
#
# SENTIMIENTO(S): good = 3
# -----------------------------------
#
# Happy : 6
# Birthday : 6
# to : 6
# one : 6
# of : 6
# my : 6
# friends : 6
# @jackgilinsky : 6
# Can't : 6
# wait : 6
# till : 6
# you're : 6
# out : 6
# in : 6
# LA! : 6
# Have : 6
# a : 6
# one! : 6
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['Happy', 'Birthday', 'to', 'one', 'of', 'my', 'best', 'friends', '@jackgilinsky', "Can't", 'wait', 'till', "you're", 'out', 'in', 'LA!', 'Have', 'a', 'good', 'one!'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 6
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): liked = 2
# -----------------------------------
#
# I : 2
# a : 2
# @YouTube : 2
# video : 2
# from : 2
# @jordzcreations : 2
# http://t.co/YJhzCimXHG : 2
# TOP : 2
# 5 : 2
# RATED : 2
# PLAYERS : 2
# IN : 2
# FIFA15! : 2
# (MESSI, : 2
# RONALDO : 2
# &amp; : 2
# IBRA!) : 2
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['I', 'liked', 'a', '@YouTube', 'video', 'from', '@jordzcreations', 'http://t.co/YJhzCimXHG', 'TOP', '5', 'RATED', 'PLAYERS', 'IN', 'FIFA15!', '(MESSI,', 'RONALDO', '&amp;', 'IBRA!)'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 2
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): competitive = 2
# -----------------------------------
#
# Hey : 2
# guys. : 2
# I : 2
# do : 2
# youtube : 2
# vidoes : 2
# for : 2
# COD : 2
# play! : 2
# Free : 2
# Agent!
# SUBSCRIBE : 2
# :) : 2
# my : 2
# youtube : 2
# is : 2
# http://m.youtube.com/user/CharlieSquires7 : 2
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['Hey', 'guys.', 'I', 'do', 'youtube', 'vidoes', 'for', 'COD', 'competitive', 'play!', 'Free', 'Agent!\nSUBSCRIBE', ':)', 'my', 'youtube', 'is', 'http://m.youtube.com/user/CharlieSquires7'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 2
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): no = -1
# -----------------------------------
#
# Para : -1
# os : -1
# interessados : -1
# em : -1
# comprar : -1
# seguidores : -1
# twitter, : -1
# curtidas : -1
# em : -1
# paginas : -1
# facebook, : -1
# etc, : -1
# entre : -1
# em : -1
# contato : -1
# twitterpublicidade@outlook.com : -1
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['Para', 'os', 'interessados', 'em', 'comprar', 'seguidores', 'no', 'twitter,', 'curtidas', 'em', 'paginas', 'no', 'facebook,', 'etc,', 'entre', 'em', 'contato', 'twitterpublicidade@outlook.com'] , TIENE UN SENTIMIENTO ASSOCIADO DE: -1
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): want = 1
# -----------------------------------
#
# RT : 1
# @disneywords: : 1
# Dreams : 1
# are : 1
# as : 1
# real : 1
# as : 1
# you : 1
# them : 1
# to : 1
# be. : 1
# Dreams : 1
# are : 1
# as : 1
# real : 1
# as : 1
# the : 1
# sky : 1
# and : 1
# the : 1
# sea. : 1
# –Peter : 1
# Pan : 1
# (Disney : 1
# Dreams) : 1
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['RT', '@disneywords:', 'Dreams', 'are', 'as', 'real', 'as', 'you', 'want', 'them', 'to', 'be.', 'Dreams', 'are', 'as', 'real', 'as', 'the', 'sky', 'and', 'the', 'sea.', '–Peter', 'Pan', '(Disney', 'Dreams)'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 1
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): adore = 3
# -----------------------------------
#
# célibataire, : 3
# le : 3
# cinéma, : 3
# les : 3
# sports, : 3
# jeux : 3
# ... : 3
#
# I'm : 3
# selling : 3
# the : 3
# pins : 3
# on : 3
# eBay : 3
# and : 3
# my : 3
# nickname : 3
# is : 3
# :
# 1mousquetaire
# Ain : 3
# - : 3
# France : 3
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['célibataire,', 'adore', 'le', 'cinéma,', 'les', 'sports,', 'jeux', '...', "\r\nI'm", 'selling', 'the', 'pins', 'on', 'eBay', 'and', 'my', 'nickname', 'is', ':\r\n1mousquetaire\r\nAin', '-', 'France'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 3
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): want = 1
# -----------------------------------
#
# Dreams : 1
# are : 1
# as : 1
# real : 1
# as : 1
# you : 1
# them : 1
# to : 1
# be. : 1
# Dreams : 1
# are : 1
# as : 1
# real : 1
# as : 1
# the : 1
# sky : 1
# and : 1
# the : 1
# sea. : 1
# –Peter : 1
# Pan : 1
# (Disney : 1
# Dreams) : 1
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['Dreams', 'are', 'as', 'real', 'as', 'you', 'want', 'them', 'to', 'be.', 'Dreams', 'are', 'as', 'real', 'as', 'the', 'sky', 'and', 'the', 'sea.', '–Peter', 'Pan', '(Disney', 'Dreams)'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 1
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): help = 2
# -----------------------------------
#
# We : 2
# can : 2
# learn : 2
# a : 2
# lot : 2
# of : 2
# things : 2
# from : 2
# Disney : 2
# characters, : 2
# and : 2
# sometimes : 2
# they : 2
# just : 2
# us : 2
# express : 2
# what : 2
# we : 2
# feel. : 2
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['We', 'can', 'learn', 'a', 'lot', 'of', 'things', 'from', 'Disney', 'characters,', 'and', 'sometimes', 'they', 'just', 'help', 'us', 'express', 'what', 'we', 'feel.'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 2
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): like = 2
# -----------------------------------
#
# @Aurinth : 2
# I : 2
# think : 2
# it's : 2
# possible, : 2
# and : 2
# sometimes : 2
# scenes : 2
# that : 2
# can : 2
# work : 2
# as : 2
# long : 2
# as : 2
# they're : 2
# bookended : 2
# by : 2
# some : 2
# sort : 2
# of : 2
# development. : 2
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['@Aurinth', 'I', 'think', "it's", 'possible,', 'and', 'sometimes', 'scenes', 'like', 'that', 'can', 'work', 'as', 'long', 'as', "they're", 'bookended', 'by', 'some', 'sort', 'of', 'development.'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 2
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): dirty = -2
# -----------------------------------
#
# Flirty, : -2
# escapism. : -2
# Erotica : -2
# author : -2
# and : -2
# alter : -2
# ego : -2
# of : -2
# @EmmieMears. : -2
# Pens : -2
# naughtiness. : -2
# NSFW-ish : -2
# Tumblr : -2
# at : -2
# http://evajamieson.tumblr.com. : -2
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['Flirty,', 'dirty', 'escapism.', 'Erotica', 'author', 'and', 'alter', 'ego', 'of', '@EmmieMears.', 'Pens', 'naughtiness.', 'NSFW-ish', 'Tumblr', 'at', 'http://evajamieson.tumblr.com.'] , TIENE UN SENTIMIENTO ASSOCIADO DE: -2
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): drunk = -2
# -----------------------------------
#
# RT : -2
# @JackAllTimeLow: : -2
# I : -2
# am : -2
# in : -2
# my : -2
# cab : -2
# and : -2
# @5SOS : -2
# came : -2
# on : -2
# radio. : -2
# I : -2
# came : -2
# too : -2
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['RT', '@JackAllTimeLow:', 'I', 'am', 'drunk', 'in', 'my', 'cab', 'and', '@5SOS', 'came', 'on', 'radio.', 'I', 'came', 'too'] , TIENE UN SENTIMIENTO ASSOCIADO DE: -2
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): was = 0
# -----------------------------------
#
# SENTIMIENTO(S): drunk = -2
# -----------------------------------
#
# I : -2
# am : -2
# in : -2
# my : -2
# cab : -2
# and : -2
# @5SOS : -2
# came : -2
# on : -2
# radio. : -2
# I : -2
# came : -2
# too : -2
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['I', 'am', 'drunk', 'in', 'my', 'cab', 'and', '@5SOS', 'came', 'on', 'radio.', 'I', 'came', 'too'] , TIENE UN SENTIMIENTO ASSOCIADO DE: -2
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): like = 2
# -----------------------------------
#
# @SingleJoCoffee : 2
# I : 2
# to : 2
# think : 2
# i : 2
# do : 2
# everything : 2
# a : 2
# rebellious : 2
# poet..... : 2
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['@SingleJoCoffee', 'I', 'like', 'to', 'think', 'i', 'do', 'everything', 'like', 'a', 'rebellious', 'poet.....'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 2
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): super = 3
# -----------------------------------
#
# The : 3
# sometimes : 3
# sane, : 3
# sometimes : 3
# coherant, : 3
# and : 3
# always : 3
# messy : 3
# ramblings : 3
# of : 3
# a : 3
# former : 3
# flight : 3
# attendant : 3
# turned : 3
# mommy : 3
# ( : 3
# at : 3
# least : 3
# in : 3
# her : 3
# own : 3
# eyes) : 3
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['The', 'sometimes', 'sane,', 'sometimes', 'coherant,', 'and', 'always', 'messy', 'ramblings', 'of', 'a', 'former', 'flight', 'attendant', 'turned', 'super', 'mommy', '(', 'at', 'least', 'in', 'her', 'own', 'eyes)'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 3
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): pray = 1
# -----------------------------------
#
# #R8 : 1
# Coming : 1
# Soon : 1
# Bitches, : 1
# for : 1
# your : 1
# pussy! : 1
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['#R8', 'Coming', 'Soon', 'Bitches,', 'pray', 'for', 'your', 'pussy!'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 1
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): fresh = 1
# -----------------------------------
#
# SENTIMIENTO(S): like = 2
# -----------------------------------
#
# SENTIMIENTO(S): struggle = -2
# -----------------------------------
#
# Need : 1
# to : 1
# get : 1
# this : 1
# trim.. : 1
# Can’t : 1
# be : 1
# boarding : 1
# plane : 1
# to : 1
# more : 1
# looking : 1
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['Need', 'to', 'get', 'this', 'fresh', 'trim..', 'Can’t', 'be', 'boarding', 'plane', 'to', 'more', 'looking', 'like', 'struggle'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 1
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): best = 3
# -----------------------------------
#
# Is : 3
# this : 3
# not : 3
# the : 3
# idea : 3
# we've : 3
# thought : 3
# of : 3
# yet? : 3
# #Dominos : 3
# #Sandwich : 3
# http://t.co/KYIBYZW9aV : 3
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['Is', 'this', 'not', 'the', 'best', 'idea', "we've", 'thought', 'of', 'yet?', '#Dominos', '#Sandwich', 'http://t.co/KYIBYZW9aV'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 3
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): was = 0
# -----------------------------------
#
# SENTIMIENTO(S): proud = 2
# -----------------------------------
#
# Goofy : 2
# gamer : 2
# and : 2
# geek! : 2
# Have : 2
# a : 2
# random : 2
# geeky : 2
# blog : 2
# and : 2
# a : 2
# WoW : 2
# transmog : 2
# blog: : 2
# http://loreleispixels.wordpress.com/ : 2
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['Goofy', 'gamer', 'and', 'proud', 'geek!', 'Have', 'a', 'random', 'geeky', 'blog', 'and', 'a', 'WoW', 'transmog', 'blog:', 'http://loreleispixels.wordpress.com/'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 2
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): mistake = -2
# -----------------------------------
#
# RT : -2
# @cthagod: : -2
# I : -2
# keep : -2
# making : -2
# the : -2
# of : -2
# talking : -2
# to : -2
# people : -2
# who : -2
# don't : -2
# know : -2
# what : -2
# they : -2
# are : -2
# talking : -2
# about....... : -2
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['RT', '@cthagod:', 'I', 'keep', 'making', 'the', 'mistake', 'of', 'talking', 'to', 'people', 'who', "don't", 'know', 'what', 'they', 'are', 'talking', 'about.......'] , TIENE UN SENTIMIENTO ASSOCIADO DE: -2
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): mistake = -2
# -----------------------------------
#
# I : -2
# keep : -2
# making : -2
# the : -2
# of : -2
# talking : -2
# to : -2
# people : -2
# who : -2
# don't : -2
# know : -2
# what : -2
# they : -2
# are : -2
# talking : -2
# about....... : -2
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['I', 'keep', 'making', 'the', 'mistake', 'of', 'talking', 'to', 'people', 'who', "don't", 'know', 'what', 'they', 'are', 'talking', 'about.......'] , TIENE UN SENTIMIENTO ASSOCIADO DE: -2
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): love = 3
# -----------------------------------
#
# SENTIMIENTO(S): support = 2
# -----------------------------------
#
# I'm : 5
# S♡NE : 5
# and : 5
# Queen's : 5
# | : 5
# I : 5
# always : 5
# SNSD : 5
# and : 5
# T-ARA : 5
# | : 5
# I : 5
# @pjy1234 : 5
# and : 5
# Jessica : 5
# snsd : 5
# | : 5
# YulSic : 5
# | : 5
# EunYeon : 5
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ["I'm", 'S♡NE', 'and', "Queen's", '|', 'I', 'always', 'support', 'SNSD', 'and', 'T-ARA', '|', 'I', 'love', '@pjy1234', 'and', 'Jessica', 'snsd', '|', 'YulSic', '|', 'EunYeon'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 5
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): love = 3
# -----------------------------------
#
# Rayda/Ray : 3
# | : 3
# 16 : 3
# | : 3
# I : 3
# draw : 3
# stuff : 3
# and : 3
# I : 3
# rainbows : 3
# | : 3
# Pokemon : 3
# ● : 3
# RT/AH : 3
# ● : 3
# RvB : 3
# ● : 3
# RWBY : 3
# ● : 3
# KnB : 3
# ● : 3
# Fe:a : 3
# ● : 3
# HQ!! : 3
# | : 3
# Talk : 3
# Shit : 3
# Get : 3
# Bipped : 3
# | : 3
# Eng/ID : 3
# ok! : 3
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['Rayda/Ray', '|', '16', '|', 'I', 'draw', 'stuff', 'and', 'I', 'love', 'rainbows', '|', 'Pokemon', '●', 'RT/AH', '●', 'RvB', '●', 'RWBY', '●', 'KnB', '●', 'Fe:a', '●', 'HQ!!', '|', 'Talk', 'Shit', 'Get', 'Bipped', '|', 'Eng/ID', 'ok!'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 3
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): waste = -1
# -----------------------------------
#
# Why : -1
# you : -1
# time : -1
# on : -1
# someone : -1
# when : -1
# they : -1
# don't : -1
# give : -1
# you : -1
# any : -1
# of : -1
# their : -1
# time : -1
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['Why', 'waste', 'you', 'time', 'on', 'someone', 'when', 'they', "don't", 'give', 'you', 'any', 'of', 'their', 'time'] , TIENE UN SENTIMIENTO ASSOCIADO DE: -1
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): best = 3
# -----------------------------------
#
# 21.06 : 3
# day : 3
# of : 3
# my : 3
# life : 3
# ❤️❤️ : 3
# #FrenchDirectioner : 3
# #MDHSFamily : 3
# #zayn's : 3
# girl : 3
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['21.06', 'best', 'day', 'of', 'my', 'life', '❤️❤️', '#FrenchDirectioner', '#MDHSFamily', "#zayn's", 'girl'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 3
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): arrested = -3
# -----------------------------------
#
# RT : -3
# @connpost: : -3
# #Milford : -3
# school : -3
# janitor : -3
# for : -3
# leaving : -3
# gifts, : -3
# notes : -3
# for : -3
# student : -3
# http://t.co/rjv7HybuFG : -3
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['RT', '@connpost:', '#Milford', 'school', 'janitor', 'arrested', 'for', 'leaving', 'gifts,', 'notes', 'for', 'student', 'http://t.co/rjv7HybuFG'] , TIENE UN SENTIMIENTO ASSOCIADO DE: -3
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): arrested = -3
# -----------------------------------
#
# #Milford : -3
# school : -3
# janitor : -3
# for : -3
# leaving : -3
# gifts, : -3
# notes : -3
# for : -3
# student : -3
# http://t.co/rjv7HybuFG : -3
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['#Milford', 'school', 'janitor', 'arrested', 'for', 'leaving', 'gifts,', 'notes', 'for', 'student', 'http://t.co/rjv7HybuFG'] , TIENE UN SENTIMIENTO ASSOCIADO DE: -3
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): no = -1
# -----------------------------------
#
# La : -1
# felicidad : -1
# esta : -1
# dentro : -1
# de : -1
# uno, : -1
# al : -1
# lado : -1
# de : -1
# alguien. : -1
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['La', 'felicidad', 'esta', 'dentro', 'de', 'uno,', 'no', 'al', 'lado', 'de', 'alguien.'] , TIENE UN SENTIMIENTO ASSOCIADO DE: -1
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): best = 3
# -----------------------------------
#
# SENTIMIENTO(S): funny = 4
# -----------------------------------
#
# (Not : 7
# affiliated : 7
# with : 7
# tumblr) : 7
# We : 7
# are : 7
# posting : 7
# and : 7
# Tumblr : 7
# captions : 7
# and : 7
# comments! : 7
# First : 7
# tweet: : 7
# 4/27/13 : 7
# Follow : 7
# us : 7
# on : 7
# Instagram:@TheBestOfTumbir : 7
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['(Not', 'affiliated', 'with', 'tumblr)', 'We', 'are', 'posting', 'funny', 'and', 'best', 'Tumblr', 'captions', 'and', 'comments!', 'First', 'tweet:', '4/27/13', 'Follow', 'us', 'on', 'Instagram:@TheBestOfTumbir'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 7
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): smiling = 2
# -----------------------------------
#
# I : 2
# know : 2
# I : 2
# am : 2
# but : 2
# look : 2
# into : 2
# my : 2
# eyes : 2
# ... : 2
# is : 2
# this : 2
# happiness? : 2
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['I', 'know', 'I', 'am', 'smiling', 'but', 'look', 'into', 'my', 'eyes', '...', 'is', 'this', 'happiness?'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 2
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): sick = -2
# -----------------------------------
#
# Ur : -2
# bud : -2
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['Ur', 'sick', 'bud'] , TIENE UN SENTIMIENTO ASSOCIADO DE: -2
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): no = -1
# -----------------------------------
#
# Boca/Cafres/Branca : -1
# 1 : -1
# sólo : -1
# ♥
# ||Socia : -1
# Adherente : -1
# N* : -1
# 66658||
# cuando : -1
# vas : -1
# a : -1
# la : -1
# cancha : -1
# vas : -1
# con : -1
# el : -1
# patrullero! : -1
# vos : -1
# tenes : -1
# aguante!! : -1
# gashina : -1
# vigilanteee!! : -1
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['Boca/Cafres/Branca', '1', 'sólo', '♥\r\n||Socia', 'Adherente', 'N*', '66658||\r\ncuando', 'vas', 'a', 'la', 'cancha', 'vas', 'con', 'el', 'patrullero!', 'vos', 'no', 'tenes', 'aguante!!', 'gashina', 'vigilanteee!!'] , TIENE UN SENTIMIENTO ASSOCIADO DE: -1
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): niggas = -5
# -----------------------------------
#
# S.O.S : -5
# Da : -5
# Navy : -5
# clique : -5
# full : -5
# of : -5
# untamed : -5
# ! : -5
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['S.O.S', 'Da', 'Navy', 'clique', 'full', 'of', 'untamed', 'niggas', '!'] , TIENE UN SENTIMIENTO ASSOCIADO DE: -5
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): no = -1
# -----------------------------------
#
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['no'] , TIENE UN SENTIMIENTO ASSOCIADO DE: -1
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): favorite = 2
# -----------------------------------
#
# SENTIMIENTO(S): love = 3
# -----------------------------------
#
# I : 5
# to : 5
# read, : 5
# draw, : 5
# play : 5
# n : 5
# watch : 5
# sports..Love : 5
# Lucero, : 5
# Fernando : 5
# Colunga, : 5
# Chayanne, : 5
# & : 5
# Alejandro : 5
# Fernandez..My : 5
# soccer : 5
# teams : 5
# are : 5
# Barcelona : 5
# & : 5
# Boca : 5
# Jrs. : 5
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['I', 'love', 'to', 'read,', 'draw,', 'play', 'n', 'watch', 'sports..Love', 'Lucero,', 'Fernando', 'Colunga,', 'Chayanne,', '&', 'Alejandro', 'Fernandez..My', 'favorite', 'soccer', 'teams', 'are', 'Barcelona', '&', 'Boca', 'Jrs.'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 5
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): hell = -4
# -----------------------------------
#
# SENTIMIENTO(S): like = 2
# -----------------------------------
#
# Sneezing : -2
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['Sneezing', 'like', 'hell'] , TIENE UN SENTIMIENTO ASSOCIADO DE: -2
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): no = -1
# -----------------------------------
#
# La : -1
# vida : -1
# se : -1
# mide : -1
# por : -1
# las : -1
# veces : -1
# que : -1
# respiras, : -1
# sino : -1
# por : -1
# aquellos : -1
# momentos : -1
# que : -1
# te : -1
# dejan : -1
# sin : -1
# aliento : -1
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['La', 'vida', 'no', 'se', 'mide', 'por', 'las', 'veces', 'que', 'respiras,', 'sino', 'por', 'aquellos', 'momentos', 'que', 'te', 'dejan', 'sin', 'aliento'] , TIENE UN SENTIMIENTO ASSOCIADO DE: -1
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): was = 0
# -----------------------------------
#
# SENTIMIENTO(S): amazing = 4
# -----------------------------------
#
# SENTIMIENTO(S): excited = 3
# -----------------------------------
#
# SENTIMIENTO(S): support = 2
# -----------------------------------
#
# RT : 9
# @Louis_Tomlinson: : 9
# The : 9
# for : 9
# the : 9
# new : 9
# album : 9
# and : 9
# Fireproof : 9
# has : 9
# been : 9
# ! : 9
# So : 9
# so : 9
# for : 9
# you : 9
# all : 9
# to : 9
# hear : 9
# more : 9
# ! : 9
# Loveeeee : 9
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['RT', '@Louis_Tomlinson:', 'The', 'support', 'for', 'the', 'new', 'album', 'and', 'Fireproof', 'has', 'been', 'amazing', '!', 'So', 'so', 'excited', 'for', 'you', 'all', 'to', 'hear', 'more', '!', 'Loveeeee'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 9
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): amazing = 4
# -----------------------------------
#
# SENTIMIENTO(S): excited = 3
# -----------------------------------
#
# SENTIMIENTO(S): support = 2
# -----------------------------------
#
# The : 9
# for : 9
# the : 9
# new : 9
# album : 9
# and : 9
# Fireproof : 9
# has : 9
# been : 9
# ! : 9
# So : 9
# so : 9
# for : 9
# you : 9
# all : 9
# to : 9
# hear : 9
# more : 9
# ! : 9
# Loveeeee : 9
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['The', 'support', 'for', 'the', 'new', 'album', 'and', 'Fireproof', 'has', 'been', 'amazing', '!', 'So', 'so', 'excited', 'for', 'you', 'all', 'to', 'hear', 'more', '!', 'Loveeeee'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 9
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): ha = 2
# -----------------------------------
#
# No : 2
# trato : 2
# de : 2
# ser : 2
# mejor : 2
# que : 2
# nadie, : 2
# trato : 2
# de : 2
# ser : 2
# lo : 2
# mejor : 2
# que : 2
# te : 2
# sucedido : 2
# en : 2
# la : 2
# vida. : 2
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['No', 'trato', 'de', 'ser', 'mejor', 'que', 'nadie,', 'trato', 'de', 'ser', 'lo', 'mejor', 'que', 'te', 'ha', 'sucedido', 'en', 'la', 'vida.'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 2
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): fun = 4
# -----------------------------------
#
# Pemalu : 4
# tp : 4
# sering : 4
# Napsuan : 4
# / : 4
# Aurat : 4
# itu : 4
# adalah : 4
# harga : 4
# diri : 4
# so : 4
# Keep : 4
# it : 4
# .Have : 4
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['Pemalu', 'tp', 'sering', 'Napsuan', '/', 'Aurat', 'itu', 'adalah', 'harga', 'diri', 'so', 'Keep', 'it', '.Have', 'fun'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 4
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): saved = 2
# -----------------------------------
#
# 1D : 2
# my : 2
# life, : 2
# WWAT : 2
# (13/07) : 2
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['1D', 'saved', 'my', 'life,', 'WWAT', '(13/07)'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 2
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): like = 2
# -----------------------------------
#
# SENTIMIENTO(S): was = 0
# -----------------------------------
#
# @Mugsy4Fly : 2
# LOL! : 2
# But : 2
# she's : 2
# a : 2
# famous : 2
# twitter : 2
# personality!!! : 2
# (It : 2
# over : 2
# Sarah : 2
# Palin,who : 2
# I : 2
# really : 2
# - : 2
# but : 2
# don't : 2
# think : 2
# should : 2
# run : 2
# for : 2
# POTUS) : 2
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['@Mugsy4Fly', 'LOL!', 'But', "she's", 'a', 'famous', 'twitter', 'personality!!!', '(It', 'was', 'over', 'Sarah', 'Palin,who', 'I', 'really', 'like', '-', 'but', "don't", 'think', 'should', 'run', 'for', 'POTUS)'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 2
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): bitter = -2
# -----------------------------------
#
# SENTIMIENTO(S): like = 2
# -----------------------------------
#
# SENTIMIENTO(S): no = -1
# -----------------------------------
#
# -Medicina : -1
# UNT- : -1
# #TJUE : -1
# 2014#
# -Resistencia, : -1
# velocidad- : -1
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['-Medicina', 'UNT-', '#TJUE', '2014#\n-Resistencia,', 'no', 'velocidad-'] , TIENE UN SENTIMIENTO ASSOCIADO DE: -1
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): offended = -2
# -----------------------------------
#
# Funniest : -2
# account : -2
# on : -2
# twitter. : -2
# *WARNING* : -2
# Do : -2
# not : -2
# follow : -2
# if : -2
# you're : -2
# easily : -2
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['Funniest', 'account', 'on', 'twitter.', '*WARNING*', 'Do', 'not', 'follow', 'if', "you're", 'easily', 'offended'] , TIENE UN SENTIMIENTO ASSOCIADO DE: -2
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): no = -1
# -----------------------------------
#
# Al : -1
# amigo : -1
# le : -1
# busques : -1
# perfecto. : -1
# Búscalo : -1
# amigo : -1
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['Al', 'amigo', 'no', 'le', 'busques', 'perfecto.', 'Búscalo', 'amigo'] , TIENE UN SENTIMIENTO ASSOCIADO DE: -1
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): ass = -4
# -----------------------------------
#
# SENTIMIENTO(S): ill = -2
# -----------------------------------
#
# @Ru_ru50 : -6
# beat : -6
# that : -6
# 19 : -6
# times : -6
# tonight : -6
# 😉😏😘 : -6
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['@Ru_ru50', 'ill', 'beat', 'that', 'ass', '19', 'times', 'tonight', '😉😏😘'] , TIENE UN SENTIMIENTO ASSOCIADO DE: -6
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): no = -1
# -----------------------------------
#
# RT : -1
# @jmfmoran: : -1
# Qué : -1
# buena : -1
# idea : -1
# llamar : -1
# al : -1
# FBI. : -1
# Total, : -1
# EEUU : -1
# abusa : -1
# de : -1
# países : -1
# a : -1
# los : -1
# que : -1
# da : -1
# ayuda : -1
# policial, : -1
# ¿cierto : -1
# Colombia : -1
# y : -1
# México? : -1
# http://t… : -1
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['RT', '@jmfmoran:', 'Qué', 'buena', 'idea', 'llamar', 'al', 'FBI.', 'Total,', 'EEUU', 'no', 'abusa', 'de', 'países', 'a', 'los', 'que', 'da', 'ayuda', 'policial,', '¿cierto', 'Colombia', 'y', 'México?', 'http://t…'] , TIENE UN SENTIMIENTO ASSOCIADO DE: -1
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): no = -1
# -----------------------------------
#
# Qué : -1
# buena : -1
# idea : -1
# llamar : -1
# al : -1
# FBI. : -1
# Total, : -1
# EEUU : -1
# abusa : -1
# de : -1
# países : -1
# a : -1
# los : -1
# que : -1
# da : -1
# ayuda : -1
# policial, : -1
# ¿cierto : -1
# Colombia : -1
# y : -1
# México? : -1
# http://t.co/pTAYMnBJQG : -1
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['Qué', 'buena', 'idea', 'llamar', 'al', 'FBI.', 'Total,', 'EEUU', 'no', 'abusa', 'de', 'países', 'a', 'los', 'que', 'da', 'ayuda', 'policial,', '¿cierto', 'Colombia', 'y', 'México?', 'http://t.co/pTAYMnBJQG'] , TIENE UN SENTIMIENTO ASSOCIADO DE: -1
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): highlight = 2
# -----------------------------------
#
# RT : 2
# @onlyxibest: : 2
# @LvBradshaw : 2
# @Monarch544 : 2
# it : 2
# will : 2
# be : 2
# the : 2
# of : 2
# my : 2
# week : 2
# #wino : 2
# 🍷 : 2
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['RT', '@onlyxibest:', '@LvBradshaw', '@Monarch544', 'it', 'will', 'be', 'the', 'highlight', 'of', 'my', 'week', '#wino', '🍷'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 2
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): good = 3
# -----------------------------------
#
# What : 3
# ever : 3
# you : 3
# are, : 3
# be : 3
# a : 3
# one : 3
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['What', 'ever', 'you', 'are,', 'be', 'a', 'good', 'one'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 3
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): highlight = 2
# -----------------------------------
#
# @LvBradshaw : 2
# @Monarch544 : 2
# it : 2
# will : 2
# be : 2
# the : 2
# of : 2
# my : 2
# week : 2
# #wino : 2
# 🍷 : 2
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['@LvBradshaw', '@Monarch544', 'it', 'will', 'be', 'the', 'highlight', 'of', 'my', 'week', '#wino', '🍷'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 2
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): downside = -2
# -----------------------------------
#
# That's : -2
# the : -2
# of : -2
# evening : -2
# shift. : -2
# When : -2
# you : -2
# work : -2
# that : -2
# day, : -2
# your : -2
# whole : -2
# day : -2
# revolves : -2
# around : -2
# it. : -2
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ["That's", 'the', 'downside', 'of', 'evening', 'shift.', 'When', 'you', 'work', 'that', 'day,', 'your', 'whole', 'day', 'revolves', 'around', 'it.'] , TIENE UN SENTIMIENTO ASSOCIADO DE: -2
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): obsessed = 2
# -----------------------------------
#
# SENTIMIENTO(S): pretty = 1
# -----------------------------------
#
# Player : 3
# 4 : 3
# on : 3
# The : 3
# Gaijin : 3
# Gamers : 3
# Play, : 3
# game : 3
# music : 3
# ocarinist, : 3
# musician : 3
# for : 3
# Game : 3
# Exchange : 3
# and : 3
# the : 3
# game : 3
# Koe : 3
# in : 3
# development. : 3
# I : 3
# tweet : 3
# some : 3
# derpy : 3
# things. : 3
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['Player', '4', 'on', 'The', 'Gaijin', 'Gamers', 'Play,', 'game', 'music', 'obsessed', 'ocarinist,', 'musician', 'for', 'Game', 'Exchange', 'and', 'the', 'game', 'Koe', 'in', 'development.', 'I', 'tweet', 'some', 'pretty', 'derpy', 'things.'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 3
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): laugh = 1
# -----------------------------------
#
# been : 1
# theA : 1
# done : 1
# that..
# #teamIDGAF
# #teamARSENAL
#  : 1
#
# @collomystiq : 1
# 's : 1
# bestie
#
# A : 1
# hearty : 1
# neva : 1
# hurts.
#
# proud : 1
# to : 1
# be : 1
# African. : 1
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['been', 'theA', 'done', 'that..\n#teamIDGAF\n#teamARSENAL\n', '\n@collomystiq', "'s", 'bestie\n\nA', 'hearty', 'laugh', 'neva', 'hurts.\n\nproud', 'to', 'be', 'African.'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 1
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): no = -1
# -----------------------------------
#
# Estuve : -1
# en : -1
# las : -1
# malas : -1
# te : -1
# abandone! : -1
# ❤Ⓒ : -1
# Ⓐ : -1
# Ⓡ : -1
# Ⓒ❤ : -1
# «Central : -1
# y : -1
# NADA : -1
# mas» : -1
# El : -1
# que : -1
# se : -1
# enamora : -1
# pierde. : -1
# SoloDeAxel♥ : -1
#  : -1
# PIN: : -1
# 2B05C746 : -1
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['Estuve', 'en', 'las', 'malas', 'no', 'te', 'abandone!', '❤Ⓒ', 'Ⓐ', 'Ⓡ', 'Ⓒ❤', '«Central', 'y', 'NADA', 'mas»', 'El', 'que', 'se', 'enamora', 'pierde.', 'SoloDeAxel♥', '', 'PIN:', '2B05C746'] , TIENE UN SENTIMIENTO ASSOCIADO DE: -1
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): no = -1
# -----------------------------------
#
# Desde : -1
# 1889 : -1
# Rosario : -1
# se : -1
# llama : -1
# CENTRAL : -1
# ! : -1
#  : -1
# / : -1
# Quema : -1
# cubiertas, : -1
# tu : -1
# alma. : -1
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['Desde', '1889', 'Rosario', 'se', 'llama', 'CENTRAL', '!', '', '/', 'Quema', 'cubiertas,', 'no', 'tu', 'alma.'] , TIENE UN SENTIMIENTO ASSOCIADO DE: -1
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): proud = 2
# -----------------------------------
#
# We’re : 2
# very : 2
# to : 2
# host : 2
# tonight's : 2
# “Evening : 2
# With : 2
# The : 2
# Mayor” : 2
# event : 2
# at : 2
# the : 2
# Greystone : 2
# Mansion. : 2
# We : 2
# are : 2
# looking : 2
# forward : 2
# to : 2
# seeing : 2
# you : 2
# there! : 2
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['We’re', 'very', 'proud', 'to', 'host', "tonight's", '“Evening', 'With', 'The', 'Mayor”', 'event', 'at', 'the', 'Greystone', 'Mansion.', 'We', 'are', 'looking', 'forward', 'to', 'seeing', 'you', 'there!'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 2
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): free = 1
# -----------------------------------
#
# Home : 1
# food : 1
# delivery : 1
# service : 1
# serving,PA,DE,NJ : 1
# & : 1
# MD. : 1
# Five : 1
# Star : 1
# restaurant : 1
# quality : 1
# delivered : 1
# to : 1
# your : 1
# door. : 1
#  : 1
# Visit : 1
# our : 1
# site : 1
# today : 1
# and : 1
# request : 1
# your : 1
# sample! : 1
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['Home', 'food', 'delivery', 'service', 'serving,PA,DE,NJ', '&', 'MD.', 'Five', 'Star', 'restaurant', 'quality', 'delivered', 'to', 'your', 'door.', '', 'Visit', 'our', 'site', 'today', 'and', 'request', 'your', 'free', 'sample!'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 1
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): no = -1
# -----------------------------------
#
# RT : -1
# @TanPajeras: : -1
# Pobre, : -1
# se : -1
# cree : -1
# sirena : -1
# y : -1
# llega : -1
# a : -1
# bagre. : -1
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['RT', '@TanPajeras:', 'Pobre,', 'se', 'cree', 'sirena', 'y', 'no', 'llega', 'a', 'bagre.'] , TIENE UN SENTIMIENTO ASSOCIADO DE: -1
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): no = -1
# -----------------------------------
#
# Pobre, : -1
# se : -1
# cree : -1
# sirena : -1
# y : -1
# llega : -1
# a : -1
# bagre. : -1
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['Pobre,', 'se', 'cree', 'sirena', 'y', 'no', 'llega', 'a', 'bagre.'] , TIENE UN SENTIMIENTO ASSOCIADO DE: -1
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): no = -1
# -----------------------------------
#
# Madridista : -1
# y : -1
# NADA : -1
# más!. : -1
# Para : -1
# el : -1
# periodismo : -1
# deportivo : -1
# español : -1
# existe : -1
# el : -1
# RESPETO : -1
# NI : -1
# LA : -1
# ÉTICA... : -1
# #MOURINHISTA. : -1
# Mi : -1
# blog: : -1
# http://t.co/AY1HNcBcUF : -1
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['Madridista', 'y', 'NADA', 'más!.', 'Para', 'el', 'periodismo', 'deportivo', 'español', 'no', 'existe', 'el', 'RESPETO', 'NI', 'LA', 'ÉTICA...', '#MOURINHISTA.', 'Mi', 'blog:', 'http://t.co/AY1HNcBcUF'] , TIENE UN SENTIMIENTO ASSOCIADO DE: -1
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): huge = 1
# -----------------------------------
#
# We : 1
# have : 1
# a : 1
# collection : 1
# of : 1
# replica : 1
# Hamilton : 1
# watches. : 1
# These : 1
# replica : 1
# Hamilton : 1
# watches : 1
# are : 1
# durable : 1
# and : 1
# luxury. : 1
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['We', 'have', 'a', 'huge', 'collection', 'of', 'replica', 'Hamilton', 'watches.', 'These', 'replica', 'Hamilton', 'watches', 'are', 'durable', 'and', 'luxury.'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 1
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): want = 1
# -----------------------------------
#
# never : 1
# not : 1
# chasing : 1
# a : 1
# million : 1
# things : 1
# i : 1
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['never', 'not', 'chasing', 'a', 'million', 'things', 'i', 'want'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 1
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): funny = 4
# -----------------------------------
#
# SENTIMIENTO(S): no = -1
# -----------------------------------
#
# SENTIMIENTO(S): was = 0
# -----------------------------------
#
# @yomaira98x : 3
# dude : 3
# u : 3
# have : 3
# idea : 3
# how : 3
# it : 3
# 😂 : 3
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['@yomaira98x', 'dude', 'u', 'have', 'no', 'idea', 'how', 'funny', 'it', 'was', '😂'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 3
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): chance = 2
# -----------------------------------
#
# SENTIMIENTO(S): win = 4
# -----------------------------------
#
# RT : 6
# @PoetryPix: : 6
# Retweet : 6
# this : 6
# tweet : 6
# for : 6
# a : 6
# to : 6
# a : 6
# small : 6
# Lokai : 6
# Bracelet. : 6
# MUST : 6
# BE : 6
# FOLLOWING. : 6
# Ends : 6
# September : 6
# 24th. : 6
# http://t.co/C1lrUAsFlg : 6
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['RT', '@PoetryPix:', 'Retweet', 'this', 'tweet', 'for', 'a', 'chance', 'to', 'win', 'a', 'small', 'Lokai', 'Bracelet.', 'MUST', 'BE', 'FOLLOWING.', 'Ends', 'September', '24th.', 'http://t.co/C1lrUAsFlg'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 6
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): like = 2
# -----------------------------------
#
# | : 2
# Drop : 2
# it : 2
# a : 2
# squat : 2
# | : 2
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['|', 'Drop', 'it', 'like', 'a', 'squat', '|'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 2
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): chance = 2
# -----------------------------------
#
# SENTIMIENTO(S): win = 4
# -----------------------------------
#
# Retweet : 6
# this : 6
# tweet : 6
# for : 6
# a : 6
# to : 6
# a : 6
# small : 6
# Lokai : 6
# Bracelet. : 6
# MUST : 6
# BE : 6
# FOLLOWING. : 6
# Ends : 6
# September : 6
# 24th. : 6
# http://t.co/C1lrUAsFlg : 6
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['Retweet', 'this', 'tweet', 'for', 'a', 'chance', 'to', 'win', 'a', 'small', 'Lokai', 'Bracelet.', 'MUST', 'BE', 'FOLLOWING.', 'Ends', 'September', '24th.', 'http://t.co/C1lrUAsFlg'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 6
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): chilling = -1
# -----------------------------------
#
# RT : -1
# @C_Rivers24: : -1
# @Calvinminds11 : -1
# I'm : -1
# honestly : -1
# just : -1
# dude : -1
# 😌 : -1
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['RT', '@C_Rivers24:', '@Calvinminds11', "I'm", 'honestly', 'just', 'chilling', 'dude', '😌'] , TIENE UN SENTIMIENTO ASSOCIADO DE: -1
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): god = 1
# -----------------------------------
#
# Avery : 1
# Calvin-GRHSHOOPS.6'1 : 1
# with : 1
# a : 1
# ratchet. : 1
# I : 1
# can : 1
# do : 1
# all : 1
# things : 1
# through : 1
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['Avery', "Calvin-GRHSHOOPS.6'1", 'with', 'a', 'ratchet.', 'I', 'can', 'do', 'all', 'things', 'through', 'god'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 1
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): chilling = -1
# -----------------------------------
#
# @Calvinminds11 : -1
# I'm : -1
# honestly : -1
# just : -1
# dude : -1
# 😌 : -1
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['@Calvinminds11', "I'm", 'honestly', 'just', 'chilling', 'dude', '😌'] , TIENE UN SENTIMIENTO ASSOCIADO DE: -1
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): die = -3
# -----------------------------------
#
# ❛❛ : -3
# Sie : -3
# sind : -3
# das : -3
# essen : -3
# und : -3
# wir : -3
# sind : -3
# Jager : -3
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['❛❛', 'Sie', 'sind', 'das', 'essen', 'und', 'wir', 'sind', 'die', 'Jager'] , TIENE UN SENTIMIENTO ASSOCIADO DE: -3
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): no = -1
# -----------------------------------
#
# RT : -1
# @augusto_rando: : -1
# Si : -1
# sabías : -1
# qué : -1
# es : -1
# la : -1
# inflación : -1
# ahora : -1
# lo : -1
# sabés : -1
# http://t.co/7Hu1sjGnMh : -1
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['RT', '@augusto_rando:', 'Si', 'no', 'sabías', 'qué', 'es', 'la', 'inflación', 'ahora', 'lo', 'sabés', 'http://t.co/7Hu1sjGnMh'] , TIENE UN SENTIMIENTO ASSOCIADO DE: -1
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): no = -1
# -----------------------------------
#
# Si : -1
# sabías : -1
# qué : -1
# es : -1
# la : -1
# inflación : -1
# ahora : -1
# lo : -1
# sabés : -1
# http://t.co/7Hu1sjGnMh : -1
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['Si', 'no', 'sabías', 'qué', 'es', 'la', 'inflación', 'ahora', 'lo', 'sabés', 'http://t.co/7Hu1sjGnMh'] , TIENE UN SENTIMIENTO ASSOCIADO DE: -1
# ...
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['simple,', 'easy', 'to', 'remember.'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 1
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): excellent = 3
# -----------------------------------
#
# SENTIMIENTO(S): expand = 1
# -----------------------------------
#
# SENTIMIENTO(S): hope = 2
# -----------------------------------
#
# Happy : 6
# Birthday : 6
# to : 6
# Robbie : 6
# , : 6
# @arsenalfantv : 6
# you : 6
# offer : 6
# insight : 6
# &amp; : 6
# coverage : 6
# on : 6
# The : 6
# Mighty : 6
# Arsenal : 6
# you : 6
# continue : 6
# to : 6
# &amp; : 6
# Innovate : 6
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['Happy', 'Birthday', 'to', 'Robbie', ',', '@arsenalfantv', 'you', 'offer', 'excellent', 'insight', '&amp;', 'coverage', 'on', 'The', 'Mighty', 'Arsenal', 'hope', 'you', 'continue', 'to', 'expand', '&amp;', 'Innovate'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 6
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): support = 2
# -----------------------------------
#
# Marketing : 2
# Student : 2
# - : 2
# @Arsenal : 2
# not : 2
# just : 2
# club : 2
# I : 2
# , : 2
# @Arsenal : 2
# is : 2
# a : 2
# life-style : 2
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['Marketing', 'Student', '-', '@Arsenal', 'not', 'just', 'club', 'I', 'support', ',', '@Arsenal', 'is', 'a', 'life-style'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 2
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): better = 2
# -----------------------------------
#
# SENTIMIENTO(S): dick = -4
# -----------------------------------
#
# SENTIMIENTO(S): no = -1
# -----------------------------------
#
# When : -3
# she : -3
# says : -3
# the : -3
# gets : -3
# every : -3
# time,,,,,,, : -3
# I : -3
# have : -3
# choice : -3
# but : -3
# to : -3
# do : -3
# the : -3
# "daddy : -3
# got : -3
# stroke : -3
# dance" : -3
# a : -3
# hahahaha : -3
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['When', 'she', 'says', 'the', 'dick', 'gets', 'better', 'every', 'time,,,,,,,', 'I', 'have', 'no', 'choice', 'but', 'to', 'do', 'the', '"daddy', 'got', 'stroke', 'dance"', 'a', 'hahahaha'] , TIENE UN SENTIMIENTO ASSOCIADO DE: -3
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): hero = 2
# -----------------------------------
#
# SENTIMIENTO(S): lol = 3
# -----------------------------------
#
# SENTIMIENTO(S): super = 3
# -----------------------------------
#
# #17708 : 8
# #mhgmg : 8
# #ca2co : 8
# just : 8
# your : 8
# average : 8
# ghetto : 8
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['#17708', '#mhgmg', '#ca2co', 'just', 'your', 'average', 'ghetto', 'super', 'hero', 'lol'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 8
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): agreed = 1
# -----------------------------------
#
# SENTIMIENTO(S): nice = 3
# -----------------------------------
#
# Dear : 4
# downstairs : 4
# neighbros: : 4
# 1:00 : 4
# PM : 4
# on : 4
# a : 4
# Wednesday : 4
# is : 4
# generally : 4
# upon : 4
# as : 4
# time : 4
# not : 4
# meant : 4
# for : 4
# turning : 4
# up. : 4
# But : 4
# try. : 4
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['Dear', 'downstairs', 'neighbros:', '1:00', 'PM', 'on', 'a', 'Wednesday', 'is', 'generally', 'agreed', 'upon', 'as', 'time', 'not', 'meant', 'for', 'turning', 'up.', 'But', 'nice', 'try.'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 4
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): better = 2
# -----------------------------------
#
# we're : 2
# together : 2
# @deamnjbb : 2
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ["we're", 'better', 'together', '@deamnjbb'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 2
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): weak = -2
# -----------------------------------
#
# Tweet : -2
# game : -2
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['Tweet', 'game', 'weak'] , TIENE UN SENTIMIENTO ASSOCIADO DE: -2
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): love = 3
# -----------------------------------
#
# SENTIMIENTO(S): no = -1
# -----------------------------------
#
# RT : 2
# @Nashgrier: : 2
# Happy : 2
# birthday : 2
# @tfionash : 2
# I : 2
# you : 2
# soooo : 2
# much! : 2
# Thank : 2
# you : 2
# for : 2
# everything, : 2
# you : 2
# have : 2
# idea : 2
# how : 2
# much : 2
# you : 2
# mean : 2
# to : 2
# me. : 2
# Hope : 2
# it'… : 2
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['RT', '@Nashgrier:', 'Happy', 'birthday', '@tfionash', 'I', 'love', 'you', 'soooo', 'much!', 'Thank', 'you', 'for', 'everything,', 'you', 'have', 'no', 'idea', 'how', 'much', 'you', 'mean', 'to', 'me.', 'Hope', "it'…"] , TIENE UN SENTIMIENTO ASSOCIADO DE: 2
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): stupid = -2
# -----------------------------------
#
# sopporting : -2
# 12 : -2
# guys : -2
# named : -2
# magcon.
# nash, : -2
# brynt, : -2
# kayden,26mgmt : -2
# follows : -2
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['sopporting', '12', 'stupid', 'guys', 'named', 'magcon.\nnash,', 'brynt,', 'kayden,26mgmt', 'follows'] , TIENE UN SENTIMIENTO ASSOCIADO DE: -2
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): good = 3
# -----------------------------------
#
# SENTIMIENTO(S): love = 3
# -----------------------------------
#
# SENTIMIENTO(S): no = -1
# -----------------------------------
#
# Happy : 5
# birthday : 5
# @tfionash : 5
# I : 5
# you : 5
# soooo : 5
# much! : 5
# Thank : 5
# you : 5
# for : 5
# everything, : 5
# you : 5
# have : 5
# idea : 5
# how : 5
# much : 5
# you : 5
# mean : 5
# to : 5
# me. : 5
# Hope : 5
# it's : 5
# a : 5
# one! : 5
# xx : 5
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['Happy', 'birthday', '@tfionash', 'I', 'love', 'you', 'soooo', 'much!', 'Thank', 'you', 'for', 'everything,', 'you', 'have', 'no', 'idea', 'how', 'much', 'you', 'mean', 'to', 'me.', 'Hope', "it's", 'a', 'good', 'one!', 'xx'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 5
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): solutions = 1
# -----------------------------------
#
# e : 1
# Global : 1
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['e', 'Global', 'solutions'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 1
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): strong = 2
# -----------------------------------
#
# Entrepreneur,smarketing : 2
# professional, : 2
# member : 2
# of : 2
# the : 2
# HubSpot : 2
# start : 2
# up : 2
# team, : 2
# believer : 2
# in : 2
# getting : 2
# things : 2
# done, : 2
# http://www.hubspot.com/dantyre : 2
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['Entrepreneur,smarketing', 'professional,', 'member', 'of', 'the', 'HubSpot', 'start', 'up', 'team,', 'strong', 'believer', 'in', 'getting', 'things', 'done,', 'http://www.hubspot.com/dantyre'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 2
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): forget = -1
# -----------------------------------
#
# RT : -1
# @katyperry: : -1
# Don't : -1
# @hernameisbanks : -1
# debut : -1
# record : -1
# GODDESS : -1
# came : -1
# out : -1
# today : -1
# &amp; : -1
# it : -1
# is : -1
# MAGNIFICENT! : -1
# https://t.co/Ja42jyk9X7 : -1
# #dontfuckwitha… : -1
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['RT', '@katyperry:', "Don't", 'forget', '@hernameisbanks', 'debut', 'record', 'GODDESS', 'came', 'out', 'today', '&amp;', 'it', 'is', 'MAGNIFICENT!', 'https://t.co/Ja42jyk9X7', '#dontfuckwitha…'] , TIENE UN SENTIMIENTO ASSOCIADO DE: -1
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): forget = -1
# -----------------------------------
#
# Don't : -1
# @hernameisbanks : -1
# debut : -1
# record : -1
# GODDESS : -1
# came : -1
# out : -1
# today : -1
# &amp; : -1
# it : -1
# is : -1
# MAGNIFICENT! : -1
# https://t.co/Ja42jyk9X7 : -1
# #dontfuckwithagoddess : -1
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ["Don't", 'forget', '@hernameisbanks', 'debut', 'record', 'GODDESS', 'came', 'out', 'today', '&amp;', 'it', 'is', 'MAGNIFICENT!', 'https://t.co/Ja42jyk9X7', '#dontfuckwithagoddess'] , TIENE UN SENTIMIENTO ASSOCIADO DE: -1
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): was = 0
# -----------------------------------
#
# SENTIMIENTO(S): freedom = 2
# -----------------------------------
#
# SENTIMIENTO(S): glory = 2
# -----------------------------------
#
# RT : 4
# @Tarunvijay: : 4
# Popularly : 4
# known : 4
# as : 4
# "Mahakavi : 4
# Bharathiyar", : 4
# he : 4
# wrote : 4
# on : 4
# of : 4
# the : 4
# Tamil : 4
# language, : 4
# and : 4
# odes : 4
# to : 4
# fighters : 4
# Tilak, : 4
# Gan… : 4
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['RT', '@Tarunvijay:', 'Popularly', 'known', 'as', '"Mahakavi', 'Bharathiyar",', 'he', 'wrote', 'on', 'glory', 'of', 'the', 'Tamil', 'language,', 'and', 'odes', 'to', 'freedom', 'fighters', 'Tilak,', 'Gan…'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 4
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): freedom = 2
# -----------------------------------
#
# SENTIMIENTO(S): glory = 2
# -----------------------------------
#
# Popularly : 4
# known : 4
# as : 4
# "Mahakavi : 4
# Bharathiyar", : 4
# he : 4
# wrote : 4
# on : 4
# of : 4
# the : 4
# Tamil : 4
# language, : 4
# and : 4
# odes : 4
# to : 4
# fighters : 4
# Tilak, : 4
# Gandhi : 4
# &amp; : 4
# Lajpat : 4
# Rai : 4
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['Popularly', 'known', 'as', '"Mahakavi', 'Bharathiyar",', 'he', 'wrote', 'on', 'glory', 'of', 'the', 'Tamil', 'language,', 'and', 'odes', 'to', 'freedom', 'fighters', 'Tilak,', 'Gandhi', '&amp;', 'Lajpat', 'Rai'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 4
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): good = 3
# -----------------------------------
#
# RT : 3
# @9GAG: : 3
# My : 3
# mood : 3
# depends : 3
# on : 3
# how : 3
# my : 3
# hair : 3
# looks. : 3
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['RT', '@9GAG:', 'My', 'mood', 'depends', 'on', 'how', 'good', 'my', 'hair', 'looks.'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 3
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): supporter = 1
# -----------------------------------
#
# #F1 : 1
# & : 1
# all : 1
# forms : 1
# of : 1
# racing : 1
# fan. : 1
# #Kubica : 1
# wherever : 1
# he : 1
# goes. : 1
# @NelsonPiquet : 1
# admirer. : 1
# #volleyball : 1
# #curling : 1
# & : 1
# more. : 1
# Schweitzophile. : 1
# #BelieveInKubica : 1
# always! : 1
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['#F1', '&', 'all', 'forms', 'of', 'racing', 'fan.', '#Kubica', 'supporter', 'wherever', 'he', 'goes.', '@NelsonPiquet', 'admirer.', '#volleyball', '#curling', '&', 'more.', 'Schweitzophile.', '#BelieveInKubica', 'always!'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 1
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): good = 3
# -----------------------------------
#
# My : 3
# mood : 3
# depends : 3
# on : 3
# how : 3
# my : 3
# hair : 3
# looks. : 3
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['My', 'mood', 'depends', 'on', 'how', 'good', 'my', 'hair', 'looks.'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 3
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): best = 3
# -----------------------------------
#
# SENTIMIENTO(S): happiness = 3
# -----------------------------------
#
# Official : 6
# Twitter : 6
# account : 6
# for : 6
# 9GAG. : 6
# 9GAG : 6
# is : 6
# your : 6
# source : 6
# of : 6
# and : 6
# awesomeness. : 6
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['Official', 'Twitter', 'account', 'for', '9GAG.', '9GAG', 'is', 'your', 'best', 'source', 'of', 'happiness', 'and', 'awesomeness.'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 6
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): like = 2
# -----------------------------------
#
# RT : 2
# @NKsubs: : 2
# Leeteuk: : 2
# Yeaaa : 2
# (gets : 2
# up)
# Kangin: : 2
# Hyung, : 2
# sit : 2
# down. : 2
# Really
# Heechul: : 2
# Don't : 2
# be : 2
# that : 2
# to : 2
# my : 2
# friend! : 2
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['RT', '@NKsubs:', 'Leeteuk:', 'Yeaaa', '(gets', 'up)\nKangin:', 'Hyung,', 'sit', 'down.', 'Really\nHeechul:', "Don't", 'be', 'like', 'that', 'to', 'my', 'friend!'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 2
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): like = 2
# -----------------------------------
#
# Leeteuk: : 2
# Yeaaa : 2
# (gets : 2
# up)
# Kangin: : 2
# Hyung, : 2
# sit : 2
# down. : 2
# Really
# Heechul: : 2
# Don't : 2
# be : 2
# that : 2
# to : 2
# my : 2
# friend! : 2
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['Leeteuk:', 'Yeaaa', '(gets', 'up)\nKangin:', 'Hyung,', 'sit', 'down.', 'Really\nHeechul:', "Don't", 'be', 'like', 'that', 'to', 'my', 'friend!'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 2
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): love = 3
# -----------------------------------
#
# SENTIMIENTO(S): share = 1
# -----------------------------------
#
# I : 4
# am : 4
# a : 4
# Professional : 4
# drummer : 4
# and : 4
# a : 4
# lover : 4
# of : 4
# the : 4
# idea : 4
# of : 4
# visualization : 4
# I : 4
# to : 4
# psitive : 4
# idas. : 4
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['I', 'am', 'a', 'Professional', 'drummer', 'and', 'a', 'lover', 'of', 'the', 'idea', 'of', 'visualization', 'I', 'love', 'to', 'share', 'psitive', 'idas.'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 4
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): like = 2
# -----------------------------------
#
# SENTIMIENTO(S): matters = 1
# -----------------------------------
#
# Life : 3
# is : 3
# Alice's : 3
# White : 3
# Rabbit. : 3
# He : 3
# runs : 3
# away : 3
# and : 3
# does : 3
# not : 3
# grab : 3
# anything, : 3
# but : 3
# this : 3
# is : 3
# not : 3
# important: : 3
# what : 3
# is : 3
# to : 3
# keep : 3
# on : 3
# pursuing : 3
# him. : 3
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['Life', 'is', 'like', "Alice's", 'White', 'Rabbit.', 'He', 'runs', 'away', 'and', 'does', 'not', 'grab', 'anything,', 'but', 'this', 'is', 'not', 'important:', 'what', 'matters', 'is', 'to', 'keep', 'on', 'pursuing', 'him.'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 3
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): thank = 2
# -----------------------------------
#
# Just : 2
# waking : 2
# up : 2
# in : 2
# the : 2
# morning : 2
# gotta : 2
# G : 2
# O : 2
# D : 2
# ❤️❤️❤️❤️❤️🙏🙏 : 2
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['Just', 'waking', 'up', 'in', 'the', 'morning', 'gotta', 'thank', 'G', 'O', 'D', '❤️❤️❤️❤️❤️🙏🙏'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 2
# ________________________________________________________________________________________________________________
#
# SENTIMIENTO(S): love = 3
# -----------------------------------
#
# ( : 3
# I : 3
# Shimazaki : 3
# Haruka)(ぱるるは初恋相手)(ぱるるに片思い中)(SONY信者)(ゲームセンターCXマニア全話見ています)(テレビプロデューサー目指しています) : 3
# ---------- COMPROBAR-----------
# EL SEGUINTE TWEET: ['(', 'I', 'love', 'Shimazaki', 'Haruka)(ぱるるは初恋相手)(ぱるるに片思い中)(SONY信者)(ゲームセンターCXマニア全話見ています)(テレビプロデューサー目指しています)'] , TIENE UN SENTIMIENTO ASSOCIADO DE: 3
# ________________________________________________________________________________________________________________

# %% [markdown]
# ### Conclusión y observaciones finales.

# %% [markdown]
# 6- Análogamente al ejercicio 1, puedo decir el ejercicio fue útil para articular la teoría con la práctica que probablemente servirá para que el alumno tenga un buen ajuste en el mundo de los negocios. Creo que el propósito del ejercicio se logró de acuerdo con mi comprensión e interpretación del ejercicio. Aunque no es obligatorio, se deben agregar algunas tareas, como limpiar los tweets, eliminar imágenes y validar los datos con la función regesp. También se eligieron los dos métodos para asignar valores (versión 1 y versión 2) a conjuntos de tweetes que no tienen valores.
# Ya que conociendo los sentimientos en el archivo sentemientos.txt, tomamos la iniciativa de que no todos los tweets en el archivo Tweets.txt nos interesan. Por ejemplo, todos los tweets con valores enteros, valores nulos y None son descartados.

# %% [markdown]
# ##### -----------------------------------------------------------------------------FIM---------------------------------------------------------------------------

# %% [markdown]
# ######  PS. El texto fue escrito en portugués y traducido al español con google translate

# %% [markdown]
# ###### Por: Adilson David Lopes Varela
